# %%
import numpy as np

# %%
from pandas import read_csv

data = read_csv('C:\Users\Biocurious\Dropbox\Thesis\AID_1851_data.csv', low_memory=False)

shape(data)

# %%
from pandas import read_csv

data = read_csv('https://www.dropbox.com/s/zayf43yzfp0ieke/AID_1851_data.csv?dl=1', low_memory=False)

shape(data)
# Out:
# (17143, 146)
# (17143, 146)

# %%
import pandas as pd
from StringIO import StringIO

df = pd.read_csv(StringIO(data), index_col=0)

# %%
data.head()
# Out:
#    PUBCHEM_SID  PUBCHEM_CID PUBCHEM_ACTIVITY_OUTCOME  PUBCHEM_ACTIVITY_SCORE  \
# 0       842238      6602638              Unspecified                     NaN
# 1       842250       644510              Unspecified                     NaN
# 2       842319      1960010              Unspecified                     NaN
# 3       842408       644675              Unspecified                     NaN
# 4       842584       644851              Unspecified                     NaN
#
#    PUBCHEM_ACTIVITY_URL  PUBCHEM_ASSAYDATA_COMMENT Inhibition Observed  \
# 0                   NaN                        NaN                True
# 1                   NaN                        NaN                True
# 2                   NaN                        NaN                True
# 3                   NaN                        NaN                True
# 4                   NaN                        NaN                True
#
#   Approved Drug Collection  Analysis Comment  Activity Outcome  \
# ...
